# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
reward = [];
c = 0;
cc = 0;
for line in open('double_dqn_reward.txt'):
    cc += float(line.strip());
    c += 1.0;
    #reward.append(line.strip());
    if (c == ):
        reward.append(cc/c);
        cc = 0;
        c = 0;
plt.plot(reward);
plt.show()

# %%
reward = [];
c = 0;
cc = 0;
label = 'training'
interval = 100;
for line in open('dueldqn_reward.txt'):
    words = line.strip().split(' ');
    if (words[0] == label):
        cc += float(words[1]);
        c += 1.0;
        #reward.append(line.strip());
        if (c == interval):
            reward.append(cc/c);
            cc = 0;
            c = 0;
plt.plot(reward);
reward = [];
c = 0;
cc = 0;
for line in open('dqn_reward.txt'):
    words = line.strip().split(' ');
    if (words[0] == label):
        cc += float(words[1]);
        c += 1.0;
        #reward.append(line.strip());
        if (c == interval):
            reward.append(cc/c);
            cc = 0;
            c = 0;
plt.plot(reward);
#print(reward);
plt.show()

# %%
reward = [];
c = 0;
cc = 0;
for line in open('dueldqn_loss.txt'):
    cc += float(line.strip());
    c += 1.0;
    #reward.append(line.strip());
    if (c == 1):
        reward.append(cc/c);
        cc = 0;
        c = 0;
plt.plot(reward);
c = 0;
cc = 0;
reward = [];
for line in open('dqn_loss.txt'):
    cc += float(line.strip());
    c += 1.0;
    #reward.append(line.strip());
    if (c == 1):
        reward.append(cc/c);
        cc = 0;
        c = 0;
plt.plot(reward);
plt.show()

# %%
import argparse
import os
import random
import gym
from gym import wrappers
import numpy as np
import matplotlib.pyplot as plt


#import deeprl_hw2 as tfrl
from deeprl_hw2.preprocessors import *;
env = gym.make('SpaceInvaders-v0')
ob = env.reset();
pre = AtariPreprocessor((84,84));
img = pre.process_state_for_memory(ob);
print img.shape
plt.imshow(img,'L',cmap='gray');
plt.show()
# Out:
# [2017-03-19 12:13:43,276] Making new env: SpaceInvaders-v0
# (84, 84)
# ValueErrorTraceback (most recent call last)
# <ipython-input-9-6a10d42ae086> in <module>()
#      15 img = pre.process_state_for_memory(ob);
#      16 print img.shape
# ---> 17 plt.imshow(img,'L');
#      18 plt.show()
#
# /usr0/home/glai1/.local/lib/python2.7/site-packages/matplotlib/pyplot.pyc in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, hold, data, **kwargs)
#    3027                         filternorm=filternorm, filterrad=filterrad,
#    3028                         imlim=imlim, resample=resample, url=url, data=data,
# -> 3029                         **kwargs)
#    3030     finally:
#    3031         ax.hold(washold)
#
# /usr0/home/glai1/.local/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1817                     warnings.warn(msg % (label_namer, func.__name__),
#    1818                                   RuntimeWarning, stacklevel=2)
# -> 1819             return func(ax, *args, **kwargs)
#    1820         pre_doc = inner.__doc__
#    1821         if pre_doc is None:
#
# /usr0/home/glai1/.local/lib/python2.7/site-packages/matplotlib/axes/_axes.pyc in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    4918         im = mimage.AxesImage(self, cmap, norm, interpolation, origin, extent,
#    4919                               filternorm=filternorm, filterrad=filterrad,
# -> 4920                               resample=resample, **kwargs)
#    4921
#    4922         im.set_data(X)
#
# /usr0/home/glai1/.local/lib/python2.7/site-packages/matplotlib/image.pyc in __init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, **kwargs)
#     595                                 filterrad=filterrad,
#     596                                 resample=resample,
# --> 597                                 **kwargs
#     598                                 )
#     599
#
# /usr0/home/glai1/.local/lib/python2.7/site-packages/matplotlib/image.pyc in __init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, **kwargs)
#     107         """
#     108         martist.Artist.__init__(self)
# --> 109         cm.ScalarMappable.__init__(self, norm, cmap)
#     110         self._mouseover = True
#     111         if origin is None:
#
# /usr0/home/glai1/.local/lib/python2.7/site-packages/matplotlib/cm.pyc in __init__(self, norm, cmap)
#     199         self.norm = norm
#     200         #: The Colormap instance of this ScalarMappable.
# --> 201         self.cmap = get_cmap(cmap)
#     202         #: The last colorbar associated with this ScalarMappable. May be None.
#     203         self.colorbar = None
#
# /usr0/home/glai1/.local/lib/python2.7/site-packages/matplotlib/cm.pyc in get_cmap(name, lut)
#     164         raise ValueError(
#     165             "Colormap %s is not recognized. Possible values are: %s"
# --> 166             % (name, ', '.join(sorted(cmap_d.keys()))))
#     167
#     168
#
# ValueError: Colormap L is not recognized. Possible values are: Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, inferno, inferno_r, jet, jet_r, magma, magma_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, seismic, seismic_r, spectral, spectral_r, spring, spring_r, summer, summer_r, terrain, terrain_r, viridis, viridis_r, winter, winter_r
