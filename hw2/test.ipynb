# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
reward = [];
c = 0;
cc = 0;
label = 'evaluate'
interval = 20;
x = np.arange(1,500)#*500;
for line in open('linearwo_reward.txt'):
    words = line.strip().split(' ');
    if (words[0] == label):
        cc += float(words[1]);
        c += 1.0;
        #reward.append(line.strip());
        if (c == interval):
            reward.append(cc/c);
            cc = 0;
            c = 0;
plt.plot(x[0:len(reward)], reward, label = 'linearwo');
c = 0;
cc = 0;
reward = [];
for line in open('linear_reward.txt'):
    words = line.strip().split(' ');
    if (words[0] == label):
        cc += float(words[1]);
        c += 1.0;
        #reward.append(line.strip());
        if (c == interval):
            reward.append(cc/c);
            cc = 0;
            c = 0;
plt.plot(x[0:len(reward)],reward,label = 'linear');
reward = [];
c = 0;
cc = 0;
for line in open('dlinear_reward.txt'):
    words = line.strip().split(' ');
    if (words[0] == label):
        cc += float(words[1]);
        c += 1.0;
        #reward.append(line.strip());
        if (c == interval):
            reward.append(cc/c);
            cc = 0;
            c = 0;
plt.plot(x[0:len(reward)], reward,label = 'dlinear');
plt.legend()
#plt.ylim(120,220)
plt.ylabel('reward');
plt.xlabel('episodes number/100000')
#print(reward);
plt.show()

# %%
reward = [];
c = 0;
cc = 0;
label = 'evaluate'
interval = 20;
x = np.arange(1,100)#*200;
for line in open('dueldqn_reward.txt'):
    words = line.strip().split(' ');
    if (words[0] == label):
        cc += float(words[1]);
        c += 1.0;
        #reward.append(line.strip());
        if (c == interval):
            reward.append(cc/c);
            cc = 0;
            c = 0;
plt.plot(x[0:len(reward)], reward, label = 'dudqn');
c = 0;
cc = 0;
reward = [];
for line in open('ddqn_reward.txt'):
    words = line.strip().split(' ');
    if (words[0] == label):
        cc += float(words[1]);
        c += 1.0;
        #reward.append(line.strip());
        if (c == interval):
            reward.append(cc/c);
            cc = 0;
            c = 0;
plt.plot(x[0:len(reward)],reward,label = 'ddqn');
reward = [];
c = 0;
cc = 0;
for line in open('dqn_reward.txt'):
    words = line.strip().split(' ');
    if (words[0] == label):
        cc += float(words[1]);
        c += 1.0;
        #reward.append(line.strip());
        if (c == interval):
            reward.append(cc/c);
            cc = 0;
            c = 0;
plt.plot(x[0:len(reward)], reward,label = 'dqn');
plt.legend()
#plt.ylim(120,300)
plt.ylabel('reward');
plt.xlabel('episodes number/100000')
#print(reward);
plt.show()

# %%
reward = [];
c = 0;
cc = 0;
x = np.arange(1,5100)*1000;
for line in open('dueldqn_loss.txt'):
    cc += float(line.strip());
    c += 1.0;
    #reward.append(line.strip());
    if (c == 1):
        reward.append(cc/c);
        cc = 0;
        c = 0;
plt.plot(x[0:len(reward)],reward,label = 'dudqn');
c = 0;
cc = 0;
reward = [];
for line in open('ddqn_loss.txt'):
    cc += float(line.strip());
    c += 1.0;
    #reward.append(line.strip());
    if (c == 1):
        reward.append(cc/c);
        cc = 0;
        c = 0;
plt.plot(x[0:len(reward)],reward,label = 'ddqn');
c = 0;
cc = 0;
reward = [];
for line in open('dqn_loss.txt'):
    cc += float(line.strip());
    c += 1.0;
    #reward.append(line.strip());
    if (c == 1):
        reward.append(cc/c);
        cc = 0;
        c = 0;
plt.plot(x[0:len(reward)],reward,label = 'dqn');
plt.legend()
plt.ylabel('training loss');
plt.xlabel('number of updating steps')
#print(reward);
plt.show()

# %%
reward = [];
c = 0;
cc = 0;
x = np.arange(1,5100)*1000;
for line in open('linearwo_loss.txt'):
    cc += float(line.strip());
    c += 1.0;
    #reward.append(line.strip());
    if (c == 1):
        reward.append(cc/c);
        cc = 0;
        c = 0;
plt.plot(x[0:len(reward)],reward,label = 'linearwo');
c = 0;
cc = 0;
reward = [];
for line in open('linear_loss.txt'):
    cc += float(line.strip());
    c += 1.0;
    #reward.append(line.strip());
    if (c == 1):
        reward.append(cc/c);
        cc = 0;
        c = 0;
plt.plot(x[0:len(reward)],reward,label = 'linear');
c = 0;
cc = 0;
reward = [];
for line in open('dlinear_loss.txt'):
    cc += float(line.strip());
    c += 1.0;
    #reward.append(line.strip());
    if (c == 1):
        reward.append(cc/c);
        cc = 0;
        c = 0;
plt.plot(x[0:len(reward)],reward,label = 'dlinear');
plt.legend()
plt.ylabel('training loss');
plt.xlabel('number of updating steps')
#print(reward);
plt.show()

# %%
import numpy as np
reward = [];
c = 0;
cc = 0;
label = 'evaluate'
for line in open('dlinear_reward.txt'):
    words = line.strip().split(' ');
    if (words[0] == label):
        reward.append(float(words[1]));
reward = reward[-100:];
reward = np.asarray(reward);
print(np.mean(reward))
print(np.std(reward))
# Out:
# 155.05
# 100.956661494
