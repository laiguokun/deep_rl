# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
reward = [];
c = 0;
cc = 0;
for line in open('double_dqn_reward.txt'):
    cc += float(line.strip());
    c += 1.0;
    if (c == 20):
        reward.append(cc/c);
        cc = 0;
        c = 0;
plt.plot(reward);
plt.show()
